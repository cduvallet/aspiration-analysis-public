# %% [markdown]
# This notebook prints out the exchanged OTUs in differentially prevalent order.

# %%
import pandas as pd
import numpy as np
from statsmodels.sandbox.stats.multicomp import multipletests


import os, sys
src_dir = os.path.normpath(os.path.join(os.getcwd(), '../util'))
sys.path.append(src_dir)
from util import convert_to_latex
# Out:
# /Users/claire/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
fpreva = '../../data/analysis/prevalence.partial_corrs.nthresh10-qthresh01-rthresh0.txt'
preva = pd.read_csv(fpreva, sep='\t')
preva.head()
# Out:
#                                                  otu  prevalence_exchange  \
# 0   k__Bacteria;p__;c__;o__;f__;g__;s__;d__denovo364             0.215909
# 1  k__Bacteria;p__Actinobacteria;c__Actinobacteri...             0.284091
# 2  k__Bacteria;p__Actinobacteria;c__Actinobacteri...             0.431818
# 3  k__Bacteria;p__Actinobacteria;c__Actinobacteri...             0.227273
# 4  k__Bacteria;p__Actinobacteria;c__Actinobacteri...             0.227273
#
#        meta_var      meta_val    site_comparison  n_patients
# 0  all_patients  all_patients  bal-gastric_fluid          88
# 1  all_patients  all_patients  bal-gastric_fluid          88
# 2  all_patients  all_patients  bal-gastric_fluid          88
# 3  all_patients  all_patients  bal-gastric_fluid          88
# 4  all_patients  all_patients  bal-gastric_fluid          88

# %%
# Number of exchange OTUs per site combination
preva.query('meta_var == "all_patients"').groupby('site_comparison').size()
# Out:
# site_comparison
# bal-gastric_fluid             76
# bal-throat_swab               13
# gastric_fluid-throat_swab    117
# dtype: int64

# %% [markdown]
# # BAL-oropharyngeal OTUs

# %%
# Let's look just at the aspirator vs. non-aspirator comparisons
preva = preva.query('meta_var == "mbs_consolidated"')

# And just the bal-throat_swab comparison
balthr_preva = preva.query('site_comparison == "bal-throat_swab"')

# %%
# Differential prevalence
diffpreva = balthr_preva.pivot(index='otu', columns='meta_val', values='prevalence_exchange')
diffpreva['asp_minus_nml'] = diffpreva['Aspiration/Penetration'] - diffpreva['Normal']
diffpreva['abs_diff'] = abs(diffpreva['asp_minus_nml'])
diffpreva.sort_values(by='abs_diff', ascending=False)
# Out:
# meta_val                                            Aspiration/Penetration  \
# otu
# k__Bacteria;p__Bacteroidetes;c__Flavobacteriia;...                    0.48
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...                    0.68
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...                    0.44
# k__Bacteria;p__Firmicutes;c__Negativicutes;o__S...                    0.60
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...                    0.76
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...                    0.68
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...                    0.40
# k__Bacteria;p__Firmicutes;c__Negativicutes;o__S...                    0.32
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...                    0.36
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...                    0.40
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...                    0.32
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...                    0.28
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...                    0.20
#
# meta_val                                              Normal  asp_minus_nml  \
# otu
# k__Bacteria;p__Bacteroidetes;c__Flavobacteriia;...  0.086957       0.393043
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...  0.304348       0.375652
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...  0.086957       0.353043
# k__Bacteria;p__Firmicutes;c__Negativicutes;o__S...  0.260870       0.339130
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.434783       0.325217
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.391304       0.288696
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...  0.130435       0.269565
# k__Bacteria;p__Firmicutes;c__Negativicutes;o__S...  0.086957       0.233043
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.173913       0.186087
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...  0.217391       0.182609
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...  0.173913       0.146087
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...  0.217391       0.062609
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...  0.173913       0.026087
#
# meta_val                                            abs_diff
# otu
# k__Bacteria;p__Bacteroidetes;c__Flavobacteriia;...  0.393043
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...  0.375652
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...  0.353043
# k__Bacteria;p__Firmicutes;c__Negativicutes;o__S...  0.339130
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.325217
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.288696
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...  0.269565
# k__Bacteria;p__Firmicutes;c__Negativicutes;o__S...  0.233043
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.186087
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...  0.182609
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...  0.146087
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...  0.062609
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...  0.026087

# %%
## Do some text manipulations to print these values out in latex table format

# Split OTU names to individual phyla
table = pd.concat((diffpreva.reset_index(), diffpreva.reset_index()['otu'].str.split(';', expand=True)), axis=1)
table['family'] = table[4].str.split('f__').str[1]
table['genus'] = table[5].str.split('g__').str[1]
# Re-format percentages
table['Aspiration/Penetration'] = table['Aspiration/Penetration'].apply(lambda x: '{:.1f}'.format(x*100))
table['Normal'] = table['Normal'].apply(lambda x: '{:.1f}'.format(x*100))
table['Difference'] = table['asp_minus_nml'].apply(lambda x: '{:.1f}'.format(x*100))
table = table.sort_values(by='asp_minus_nml', ascending=False)

col_order = ['family', 'genus', 'Normal', 'Aspiration/Penetration', 'Difference']
table = table[col_order]
print('\n'.join(table.apply(convert_to_latex, axis=1)))
# Out:
# Flavobacteriaceae &  & 8.7 & 48.0 & 39.3 \\
# Fusobacteriaceae & Fusobacterium & 30.4 & 68.0 & 37.6 \\
# Micrococcaceae & Rothia & 8.7 & 44.0 & 35.3 \\
# Veillonellaceae & Veillonella & 26.1 & 60.0 & 33.9 \\
# Prevotellaceae &  & 43.5 & 76.0 & 32.5 \\
# Porphyromonadaceae & Porphyromonas & 39.1 & 68.0 & 28.9 \\
# Streptococcaceae & Streptococcus & 13.0 & 40.0 & 27.0 \\
# Veillonellaceae & Centipeda & 8.7 & 32.0 & 23.3 \\
# Prevotellaceae & Prevotella & 17.4 & 36.0 & 18.6 \\
# Leptotrichiaceae & Streptobacillus & 21.7 & 40.0 & 18.3 \\
# Fusobacteriaceae & Fusobacterium & 17.4 & 32.0 & 14.6 \\
# Aerococcaceae & Abiotrophia & 21.7 & 28.0 & 6.3 \\
# Neisseriaceae & Neisseria & 17.4 & 20.0 & 2.6 \\

# %%
# How many patients were used for these prevalence calcs?
balthr_preva[['meta_val', 'n_patients']].drop_duplicates()
# Out:
#                     meta_val  n_patients
# 1305  Aspiration/Penetration          25
# 1318                  Normal          23

# %% [markdown]
# # BAL-gastric OTUs

# %%
balgas_preva = preva.query('site_comparison == "bal-gastric_fluid"')

# Pivot to get differential prevalence
diffpreva = balgas_preva.pivot(index='otu', columns='meta_val', values='prevalence_exchange')

# Sort values by differential prevalence in aspirators
diffpreva['asp_minus_nml'] = diffpreva['Aspiration/Penetration'] - diffpreva['Normal']
#diffpreva['abs_diff'] = abs(diffpreva['asp_minus_nml'])
diffpreva.sort_values(by='asp_minus_nml', ascending=False).head(10)
# Out:
# meta_val                                            Aspiration/Penetration  \
# otu
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...                0.413793
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...                0.620690
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...                0.827586
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...                0.379310
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...                0.413793
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...                0.517241
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...                0.586207
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...                0.689655
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...                0.827586
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...                0.413793
#
# meta_val                                              Normal  asp_minus_nml
# otu
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...  0.071429       0.342365
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.285714       0.334975
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...  0.500000       0.327586
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.107143       0.272167
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...  0.142857       0.270936
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.250000       0.267241
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...  0.321429       0.264778
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...  0.428571       0.261084
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...  0.571429       0.256158
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...  0.178571       0.235222

# %%
## Do some text manipulations to print these values out in latex table format
table = pd.concat((diffpreva.reset_index(), diffpreva.reset_index()['otu'].str.split(';', expand=True)), axis=1)

# Split OTU names to individual phyla
# Prettify results
table['family'] = table[4].str.split('f__').str[1]
table['genus'] = table[5].str.split('g__').str[1]

# Fill in empty families with order
table['family'] = table['family'].where(table['family'] != '', "Unknown " + table[3].str.split('o__').str[1])
# Fill in empty orders with "Unkown bacteria" (I checked manually that this one is unannotated all the way)
table['family'] = table['family'].where(table['family'] != 'Unknown ', "Unknown Bacteria")

# Re-format percentages
table['Aspiration/Penetration'] = table['Aspiration/Penetration'].apply(lambda x: '{:.1f}'.format(x*100))
table['Normal'] = table['Normal'].apply(lambda x: '{:.1f}'.format(x*100))
table['Difference'] = table['asp_minus_nml'].apply(lambda x: '{:.1f}'.format(x*100))

table = table.sort_values(by='asp_minus_nml', ascending=False)

col_order = ['family', 'genus', 'Normal', 'Aspiration/Penetration', 'Difference']

# Print Ruminococcus2 in response to reviewer comments
print(table.query('genus == "Ruminococcus2"')['otu'].values)

table = table[col_order]
print('\n'.join(table.apply(convert_to_latex, axis=1)))
# Out:
# ['k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Lachnospiraceae;g__Ruminococcus2;s__;d__denovo57']
# Neisseriaceae & Neisseria & 7.1 & 41.4 & 34.2 \\
# Porphyromonadaceae & Porphyromonas & 28.6 & 62.1 & 33.5 \\
# Pasteurellaceae & Haemophilus & 50.0 & 82.8 & 32.8 \\
# Lachnospiraceae & Coprococcus & 10.7 & 37.9 & 27.2 \\
# Micrococcaceae & Rothia & 14.3 & 41.4 & 27.1 \\
# Prevotellaceae & Prevotella & 25.0 & 51.7 & 26.7 \\
# Carnobacteriaceae & Granulicatella & 32.1 & 58.6 & 26.5 \\
# Bacillales\_Incertae\_Sedis\_XI & Gemella & 42.9 & 69.0 & 26.1 \\
# Pasteurellaceae & Haemophilus & 57.1 & 82.8 & 25.6 \\
# Actinomycetaceae & Actinomyces & 17.9 & 41.4 & 23.5 \\
# Streptococcaceae & Streptococcus & 39.3 & 62.1 & 22.8 \\
# Lachnospiraceae & Oribacterium & 14.3 & 34.5 & 20.2 \\
# Leptotrichiaceae & Streptobacillus & 17.9 & 37.9 & 20.1 \\
# Lachnospiraceae & Lachnoanaerobaculum & 17.9 & 37.9 & 20.1 \\
# Fusobacteriaceae & Fusobacterium & 42.9 & 62.1 & 19.2 \\
# Prevotellaceae &  & 50.0 & 69.0 & 19.0 \\
# Flavobacteriaceae & Planobacterium & 14.3 & 31.0 & 16.7 \\
# Leptotrichiaceae & Leptotrichia & 14.3 & 31.0 & 16.7 \\
# Erysipelotrichaceae & Solobacterium & 17.9 & 34.5 & 16.6 \\
# Prevotellaceae & Prevotella & 21.4 & 37.9 & 16.5 \\
# Pasteurellaceae & Haemophilus & 28.6 & 44.8 & 16.3 \\
# Veillonellaceae & Veillonella & 35.7 & 51.7 & 16.0 \\
# Enterobacteriaceae & Escherichia/Shigella & 46.4 & 62.1 & 15.6 \\
# Prevotellaceae &  & 46.4 & 62.1 & 15.6 \\
# Neisseriaceae & Neisseria & 60.7 & 75.9 & 15.1 \\
# Streptococcaceae & Streptococcus & 75.0 & 89.7 & 14.7 \\
# Veillonellaceae & Veillonella & 35.7 & 48.3 & 12.6 \\
# Prevotellaceae & Prevotella & 42.9 & 55.2 & 12.3 \\
# Micrococcaceae & Rothia & 42.9 & 55.2 & 12.3 \\
# Streptococcaceae & Streptococcus & 42.9 & 55.2 & 12.3 \\
# Prevotellaceae & Prevotella & 64.3 & 75.9 & 11.6 \\
# Unknown Burkholderiales &  & 10.7 & 20.7 & 10.0 \\
# Bacteroidaceae & Bacteroides & 14.3 & 24.1 & 9.9 \\
# Porphyromonadaceae & Porphyromonas & 21.4 & 31.0 & 9.6 \\
# Moraxellaceae & Moraxella & 39.3 & 48.3 & 9.0 \\
# Prevotellaceae & Prevotella & 57.1 & 65.5 & 8.4 \\
# Leptotrichiaceae & Leptotrichia & 21.4 & 27.6 & 6.2 \\
# Fusobacteriaceae & Fusobacterium & 25.0 & 31.0 & 6.0 \\
# Porphyromonadaceae & Porphyromonas & 50.0 & 55.2 & 5.2 \\
# Neisseriaceae & Neisseria & 17.9 & 20.7 & 2.8 \\
# Veillonellaceae & Veillonella & 89.3 & 89.7 & 0.4 \\
# Coriobacteriaceae & Atopobium & 21.4 & 20.7 & -0.7 \\
# Unknown Bacteria &  & 21.4 & 20.7 & -0.7 \\
# Enterococcaceae &  & 85.7 & 82.8 & -3.0 \\
# Chloroplast & Streptophyta & 10.7 & 6.9 & -3.8 \\
# Pasteurellaceae & Haemophilus & 17.9 & 13.8 & -4.1 \\
# Unknown Bacillales &  & 17.9 & 13.8 & -4.1 \\
# Unknown Bacillales &  & 17.9 & 13.8 & -4.1 \\
# Lactobacillaceae & Lactobacillus & 28.6 & 17.2 & -11.3 \\
# Pasteurellaceae & Haemophilus & 32.1 & 20.7 & -11.5 \\
# Staphylococcaceae & Staphylococcus & 60.7 & 48.3 & -12.4 \\
# Bacteroidaceae & Bacteroides & 17.9 & 3.4 & -14.4 \\
# Comamonadaceae & Acidovorax & 17.9 & 3.4 & -14.4 \\
# Porphyromonadaceae & Parabacteroides & 21.4 & 6.9 & -14.5 \\
# Comamonadaceae & Pelomonas & 21.4 & 6.9 & -14.5 \\
# Flavobacteriaceae & Chryseobacterium & 28.6 & 13.8 & -14.8 \\
# Erysipelotrichaceae & Clostridium\_XVIII & 21.4 & 3.4 & -18.0 \\
# Lachnospiraceae & Ruminococcus2 & 25.0 & 6.9 & -18.1 \\
# Flavobacteriaceae & Chryseobacterium & 50.0 & 31.0 & -19.0 \\
# Neisseriaceae & Microvirgula & 57.1 & 37.9 & -19.2 \\
# Enterobacteriaceae & Enterobacter & 82.1 & 62.1 & -20.1 \\
# Mycobacteriaceae & Mycobacterium & 28.6 & 6.9 & -21.7 \\
# Moraxellaceae & Acinetobacter & 60.7 & 37.9 & -22.8 \\
# Streptococcaceae & Streptococcus & 60.7 & 37.9 & -22.8 \\
# Bacteroidaceae & Bacteroides & 53.6 & 27.6 & -26.0 \\
# Unknown Bacillales &  & 57.1 & 31.0 & -26.1 \\
# Moraxellaceae & Acinetobacter & 60.7 & 34.5 & -26.2 \\
# Moraxellaceae & Enhydrobacter & 60.7 & 34.5 & -26.2 \\
# Lactobacillaceae & Lactobacillus & 50.0 & 20.7 & -29.3 \\
# Aeromonadaceae & Aeromonas & 57.1 & 27.6 & -29.6 \\
# Moraxellaceae & Acinetobacter & 78.6 & 41.4 & -37.2 \\
# Leuconostocaceae & Weissella & 78.6 & 37.9 & -40.6 \\
# Moraxellaceae & Acinetobacter & 78.6 & 37.9 & -40.6 \\
# Leuconostocaceae & Leuconostoc & 78.6 & 37.9 & -40.6 \\
# Streptococcaceae & Lactococcus & 78.6 & 37.9 & -40.6 \\
# Streptococcaceae & Lactococcus & 78.6 & 37.9 & -40.6 \\

# %%
# how many patients were used for these prevalence calcs?
balgas_preva[['meta_val', 'n_patients']].drop_duplicates()
# Out:
#                    meta_val  n_patients
# 76   Aspiration/Penetration          29
# 152                  Normal          28

# %% [markdown]
# # Significance

# %%
fname = '../../data/analysis/exchange.with_partial_corrs.null_20reps.txt'

nthresh = 10
rthresh = 0
qthresh = 0.1

df = pd.read_csv(fname, sep='\t')

df = df.query('n_partial >= @nthresh')
df.head()
# Out:
#                                                  otu          site1  \
# 0   k__Bacteria;p__;c__;o__;f__;g__;s__;d__denovo364            bal
# 2  k__Bacteria;p__Actinobacteria;c__Actinobacteri...  gastric_fluid
# 3  k__Bacteria;p__Actinobacteria;c__Actinobacteri...            bal
# 4  k__Bacteria;p__Actinobacteria;c__Actinobacteri...            bal
# 5  k__Bacteria;p__Actinobacteria;c__Actinobacteri...  gastric_fluid
#
#            site2          site3  r_site12  p_site12  n_site12  r_partial  \
# 0  gastric_fluid    throat_swab  0.337461  0.170838        18   0.338192
# 2    throat_swab            bal -0.207389  0.280370        29  -0.207650
# 3  gastric_fluid    throat_swab  0.230943  0.301112        22   0.227302
# 4    throat_swab  gastric_fluid  0.360870  0.083195        24   0.332241
# 5    throat_swab            bal -0.137014  0.222569        81  -0.138964
#
#    p_partial  n_partial  shuffle_iter
# 0     0.0930         13             0
# 2     0.8665         18             0
# 3     0.1570         12             0
# 4     0.0440         20             0
# 5     0.8940         47             0

# %%
# Need to correct for multiple tests within each iteration only
for g, subdf in df.groupby('shuffle_iter'):
    _, df.loc[subdf.index, 'q_partial'], _, _ = multipletests(subdf['p_partial'], method='fdr_bh')

df.head()
# Out:
#                                                  otu          site1  \
# 0   k__Bacteria;p__;c__;o__;f__;g__;s__;d__denovo364            bal
# 2  k__Bacteria;p__Actinobacteria;c__Actinobacteri...  gastric_fluid
# 3  k__Bacteria;p__Actinobacteria;c__Actinobacteri...            bal
# 4  k__Bacteria;p__Actinobacteria;c__Actinobacteri...            bal
# 5  k__Bacteria;p__Actinobacteria;c__Actinobacteri...  gastric_fluid
#
#            site2          site3  r_site12  p_site12  n_site12  r_partial  \
# 0  gastric_fluid    throat_swab  0.337461  0.170838        18   0.338192
# 2    throat_swab            bal -0.207389  0.280370        29  -0.207650
# 3  gastric_fluid    throat_swab  0.230943  0.301112        22   0.227302
# 4    throat_swab  gastric_fluid  0.360870  0.083195        24   0.332241
# 5    throat_swab            bal -0.137014  0.222569        81  -0.138964
#
#    p_partial  n_partial  shuffle_iter  q_partial
# 0     0.0930         13             0   0.682297
# 2     0.8665         18             0   0.982952
# 3     0.1570         12             0   0.805345
# 4     0.0440         20             0   0.495000
# 5     0.8940         47             0   0.982952

# %%
exchanged = df.query('(r_partial > @rthresh) & (q_partial < @qthresh)')
exchanged['site_comparison'] = exchanged['site1'] + '-' + exchanged['site2']
exchanged.groupby(['shuffle_iter', 'site_comparison']).size()
# Out:
# /Users/claire/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# shuffle_iter  site_comparison
# 5             gastric_fluid-throat_swab    1
# 6             bal-gastric_fluid            1
#               gastric_fluid-throat_swab    1
# 10            bal-gastric_fluid            2
#               bal-throat_swab              2
# 13            bal-gastric_fluid            1
# dtype: int64

# %% [markdown]
# The dataframe above shows how many OTUs were found to be exchanged in each shuffle iteration
